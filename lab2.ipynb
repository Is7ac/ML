# %% [markdown]
# <a href="https://colab.research.google.com/github/Is7ac/ML/blob/main/lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Data
x1 = np.array([1, 5, 7, 2])
x2 = np.array([1, 2, 2, 3])
y = np.array([2, 4, 2, 4])

# Plotting the data
plt.scatter(x1, y, color='red', label='X1')
plt.scatter(x2, y, color='blue', label='X2')
plt.xlabel('X1, X2')
plt.ylabel('Y')
plt.title('Scatter Plot of Data')
plt.legend()
plt.grid(True)
plt.show()

# %%
theta = np.array([3, 0.5])
learning_rate = 0.25
iterations = 4

# %%
def hypothesis(x, theta):
    return theta[0] + theta[1] * x

# %%
def mean_squared_error(y_true, y_pred):
    return np.mean((y_true - y_pred) ** 2)

# %%
losses = []
for i in range(iterations):
    # Prediction
    y_pred = hypothesis(x1, theta) + hypothesis(x2, theta)

    # Compute gradients
    grad0 = np.mean(y_pred - y)
    grad1 = np.mean((y_pred - y) * x1)
    grad2 = np.mean((y_pred - y) * x2)

    # Update parameters
    theta[0] -= learning_rate * grad0
    theta[1] -= learning_rate * grad1
    theta[1] -= learning_rate * grad2

    # Compute loss
    loss = mean_squared_error(y, y_pred)
    losses.append(loss)

    # Plot regression model
    plt.scatter(x1, y, color='red', label='X1')
    plt.scatter(x2, y, color='blue', label='X2')
    plt.plot(x1, hypothesis(x1, theta), color='green', label='Regression Model')
    plt.xlabel('X1, X2')
    plt.ylabel('Y')
    plt.title('Regression Model after Iteration {}'.format(i+1))
    plt.legend()
    plt.grid(True)
    plt.show()

    print("Iteration {}: Theta = {}, Loss = {}".format(i+1, theta, loss))

# Plot loss curve
plt.plot(range(1, iterations+1), losses, marker='o')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.title('Loss Curve')
plt.grid(True)
plt.show()
# Out:
# Iteration 1: Theta = [ 1.53125 -8.71875], Loss = 36.9375
# Iteration 2: Theta = [14.04882812 77.89648438], Loss = 3020.756591796875
# Iteration 3: Theta = [-104.20178223 -732.21520996], Loss = 264272.1903181076
# Iteration 4: Theta = [1001.20847321 6848.12856293], Loss = 23136706.755493682

# %% [markdown]
# in the initial iteration the loss was 36.9375 but in the final one the loss became over 23136706.755493682!!
# it didn't improve
