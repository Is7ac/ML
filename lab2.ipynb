# %% [markdown]
# <a href="https://colab.research.google.com/github/Is7ac/ML/blob/main/lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# we will need almost 3 parameters for this problem
# B0 for bias
# B1 for X1
# B2 for X2

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Data
x1 = np.array([1, 5, 7, 2])
x2 = np.array([1, 2, 2, 3])
y = np.array([2, 4, 2, 4])

# Plotting the data
plt.scatter(x2, y, color='blue', label='X2')
plt.xlabel('X2')
plt.ylabel('Y')
plt.title('Scatter Plot of Data')
plt.legend()
plt.grid(True)
plt.show()

# %%
theta = np.array([3, 0.5])
learning_rate = 0.25
iterations = 4

# %%
def hypothesis(x, theta):
    return theta[0] + theta[1] * x

# %%
def mean_squared_error(y_true, y_pred):
    return np.mean((y_true - y_pred) ** 2)

# %%
losses = []
for i in range(iterations):
    # Prediction
    y_pred = hypothesis(x2, theta)

    # Compute gradients
    grad0 = np.mean(y_pred - y)
    grad1 = np.mean((y_pred - y) * x2)

    # Update parameters
    theta[0] -= learning_rate * grad0
    theta[1] -= learning_rate * grad1

    # Compute loss
    loss = mean_squared_error(y, y_pred)
    losses.append(loss)

    # Plot regression model
    plt.scatter(x2, y, color='blue', label='X2')
    plt.plot(x2, hypothesis(x2, theta), color='green', label='Regression Model')
    plt.xlabel('X2')
    plt.ylabel('Y')
    plt.title('Regression Model after Iteration {}'.format(i+1))
    plt.legend()
    plt.grid(True)
    plt.show()

    print("Iteration {}: Theta = {}, Loss = {}".format(i+1, theta, loss))

# Plot loss curve
plt.plot(range(1, iterations+1), losses, marker='o')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.title('Loss Curve')
plt.grid(True)
plt.show()
# Out:
# Iteration 1: Theta = [2.78125   0.2421875], Loss = 0.955078125
# Iteration 2: Theta = [2.71484375 0.20410156], Loss = 0.857696533203125
# Iteration 3: Theta = [2.68408203 0.24206543], Loss = 0.8318676948547363
# Iteration 4: Theta = [2.64202881 0.25270081], Loss = 0.8155279830098152

# %% [markdown]
# in the initial iteration the loss was 0.955078125 but in the final one the loss became 0.8155279830098152!!
# it improved!

# %%
theta = np.array([3, 0.5])
learning_rate = 0.01
iterations = 4

# %%
losses = []
for i in range(iterations):
    # Prediction
    y_pred = hypothesis(x2, theta)

    # Compute gradients
    grad0 = np.mean(y_pred - y)
    grad1 = np.mean((y_pred - y) * x2)

    # Update parameters
    theta[0] -= learning_rate * grad0
    theta[1] -= learning_rate * grad1

    # Compute loss
    loss = mean_squared_error(y, y_pred)
    losses.append(loss)

    # Plot regression model
    plt.scatter(x2, y, color='blue', label='X2')
    plt.plot(x2, hypothesis(x2, theta), color='green', label='Regression Model')
    plt.xlabel('X2')
    plt.ylabel('Y')
    plt.title('Regression Model after Iteration {}'.format(i+1))
    plt.legend()
    plt.grid(True)
    plt.show()

    print("Iteration {}: Theta = {}, Loss = {}".format(i+1, theta, loss))

# Plot loss curve
plt.plot(range(1, iterations+1), losses, marker='o')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.title('Loss Curve')
plt.grid(True)
plt.show()
# Out:
# Iteration 1: Theta = [2.99   0.4825], Loss = 1.625
# Iteration 2: Theta = [2.98045   0.4659875], Loss = 1.545928125
# Iteration 3: Theta = [2.97132575 0.45040906], Loss = 1.4751040557031254
# Iteration 4: Theta = [2.96260431 0.43571414], Loss = 1.41166003799108

# %%
theta = np.array([3, 0.5])
learning_rate = 0.5
iterations = 4

# %%
losses = []
for i in range(iterations):
    # Prediction
    y_pred = hypothesis(x2, theta)

    # Compute gradients
    grad0 = np.mean(y_pred - y)
    grad1 = np.mean((y_pred - y) * x2)

    # Update parameters
    theta[0] -= learning_rate * grad0
    theta[1] -= learning_rate * grad1

    # Compute loss
    loss = mean_squared_error(y, y_pred)
    losses.append(loss)

    # Plot regression model
    plt.scatter(x2, y, color='blue', label='X2')
    plt.plot(x2, hypothesis(x2, theta), color='green', label='Regression Model')
    plt.xlabel('X2')
    plt.ylabel('Y')
    plt.title('Regression Model after Iteration {}'.format(i+1))
    plt.legend()
    plt.grid(True)
    plt.show()

    print("Iteration {}: Theta = {}, Loss = {}".format(i+1, theta, loss))

# Plot loss curve
plt.plot(range(1, iterations+1), losses, marker='o')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.title('Loss Curve')
plt.grid(True)
plt.show()
# Out:
# Iteration 1: Theta = [ 2.5   -0.375], Loss = 1.625
# Iteration 2: Theta = [3.125   1.21875], Loss = 3.0078125
# Iteration 3: Theta = [ 1.84375   -1.3984375], Loss = 7.09033203125
# Iteration 4: Theta = [3.8203125  3.15429688], Loss = 19.003448486328125

# %% [markdown]
# Early Stop:
#
# Early stopping is a regularization technique used to prevent overfitting in machine learning models, particularly in iterative optimization algorithms like gradient descent.
#
# Overshoot:
# ![WhatsApp Image 2024-03-11 at 10.40.19_31f1a002.jpg](data:image/jpeg;base64,...)
# Overshoot occurs when an optimization algorithm, such as gradient descent, updates the parameters of a model too aggressively, causing it to move past the optimal solution and oscillate around it.
